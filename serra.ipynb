# %%
print("Restorana hosgeldiniz")
print("""=====MENU=====
        Pizza
        Corba
        Makarna
        Pilav
        Icecek
==============""")
adS = input("Lütfen isim-soyisim giriniz")
Budget = int(input("Lütfen bütçenizi giriniz: "))
kisi = int(input("Lütfen kaç kişinin sipariş vereceğini giriniz: "))
class Menu:
  def __init__(self,isim,fiyat):
    self.isim = isim
    self.fiyat = fiyat
    
class Pizza(Menu):
  def __init__(self, isim, fiyat, icindekiler,boy,kenar,sos):
      super().__init__(isim, fiyat)
      self.icindekiler = icindekiler
      self.boy = boy
      self.kenar = kenar
      self.sos = sos
  def SiparisGoster(self):
        print(f"AD-Soyad:{adS}, Sipariş: {self.isim}, Fiyat:{self.fiyat}, İçindekiler: {self.icindekiler}, Sosu: {self.sos}, Kalan Bütçe: {Budget-self.fiyat}")
  
  def siparis(self):
    s = input("siparisi onayliyor musunuz?: ")
    print("Onayliyor mususnuz:" , s)
    if s == "hayir":
        e = input(("Eklemek ıstedıgınız urun: "))
        c = input(("Cıkartmak ıstedıgınız urun: "))
        if e == "yok":
           pass
        else:       
            self.icindekiler.append(e)
        if c == "yok":
            pass
        else: 
            self.icindekiler.remove(c)
    else:
        print("siparisiniz kaydedildi")
     
  
class Çorba(Menu):
    def __init__(self, isim, fiyat):
      super().__init__(isim, fiyat)
      
    def SiparisGoster(self):
        print(f"AD-Soyad:{adS}, Sipariş: {self.isim}, Fiyat:{self.fiyat}, Baharat : {baharat} Kalan Bütçe: {Budget-self.fiyat}")

class Makarna(Menu):
    def __init__(self, isim, fiyat):
      super().__init__(isim, fiyat )
      

    def SiparisGoster(self):
        print(f"AD-Soyad:{adS}, Sipariş: {self.isim}, Sos: {sos} Fiyat:{self.fiyat}, Kalan Bütçe: {Budget-self.fiyat}")       

class Pilav(Menu):
    def __init__(self, isim, fiyat,cesit):
      super().__init__(isim, fiyat)
      self.cesit = cesit
    def SiparisGoster(self):
        print(f"AD-Soyad:{adS}, Sipariş: {self.isim}, Cesit: {self.cesit} Fiyat:{self.fiyat}, Kalan Bütçe: {Budget-self.fiyat}")

class Icecek(Menu):
    def _init_(self, isim, fiyat):
      super()._init_(isim, fiyat)
     
    def SiparisGoster(self):
      print(f"AD-Soyad:{adS}, Sipariş: {self.isim}, Boyut: {b} Fiyat:{self.fiyat}, Kalan Bütçe: {Budget-self.fiyat}")


#hata bloğ u menüde olmayanlaar için ne yapılacağı, menüler, içindekieri değiştirebilir kullanıcı, 
pmenu = (""" ------MENU--------
      1. Margarıta
      2. VeggıePızza
      3. Etlı Pızza""")
cmenu = (""" ------MENU--------
      1. Mercimek 
      2. Yayla Çorbası
      3. Tarhana Çorbası """)
mmenu = (""" ------MENU--------
      1. Spagetti  
      2. kelebek makarna
      3.  boncuk makarna """)
imenu = (""" ------MENU--------
      1. Nohutlu Pilav  
      2. Tavuklu Pilav
      3.  Bulgur Pilavı """)
icecek = (""" ------MENU--------
      1. Coca Cola  
      2. Ayran
      3. Ice Tea
      4. Fanta
      5. Meyve Suyu """)

l1 = ["mozarella", "domates"]
l2 = ["mozarella", "domates", "biber", "patlican"]
l3 = ["mozarella", "domates", "sucuk"]
pmenusozluk = {"1" :['Margarıta', 10, l1], "2" : ["VeggiePizza" , 12,l2], "3" :[ "EtliPizza" , 15, l3]}
cmenusozluk = {"1" :['Mercimek', 10], "2" : ["Yayla Çorbası" , 12], "3" :[ "Tarhana Çorbası" , 15]}
mmenusozluk = {"1" :['Spagetti', 10], "2" : ["Kelebek" , 12], "3" :[ "Boncuk makarna" , 15]}
imenusozluk = {"1" :['Nohutlu Pilav', 40], "2" : ["Tavuklu Pilav" , 40], "3" :[ "Bulgur Pilavı" , 40]}
icmenusozluk = {"1" :['Coca Cola', 20], "2" : ["Ayran" , 10], "3" :[ "Ice Tea" , 40], "4" : ["Fanta" , 15], "5" : ["Meyve Suyu", 10]}
while True:
    durum = False
    secim = int(input("Sipariş vermek istiyorsanız lütfen 1'e , sipariş vermek istemiyorsanız lütfen 0'a basın."))
    if secim == 0:
       break
    elif secim == 1:
        urun = input("Sıparıs vermek ıstedıgınız urunu secın: ")
        print("MENU")
        
        
        if urun == "pizza":
           
            sayi = int(input("Lütfen kac adet pizza siparis edeceginizi giriniz: "))
            print(pmenu)
            for i in range(sayi):
              siparis = input("Lutfen {} numarali sıparısinizi gırınız" .format(i+1) )
              boy =input("Lütfen boyutunu giriniz:")
              kenar = input("Lütfen kenarı giriniz:")
              sos = input("Lutfen sos giriniz: ")
              if siparis == '1':
                pizza = Pizza(isim= pmenusozluk[(siparis)][0], fiyat = pmenusozluk[(siparis)][1] , icindekiler=pmenusozluk[(siparis)][2] , boy = boy, kenar = kenar, sos = sos)
                print("Icındekıler: ", l1)
                pizza.siparis()
                pizza.SiparisGoster()


              elif siparis == '2':
                pizza = Pizza(isim= pmenusozluk[(siparis)][0], fiyat = pmenusozluk[(siparis)][1] , icindekiler=pmenusozluk[(siparis)][2] , boy = boy, kenar = kenar, sos = sos)
                print("Icındekıler: ", l2)
                pizza.siparis()
                pizza.SiparisGoster()
            
              elif siparis == '3':
                pizza = Pizza(isim= pmenusozluk[(siparis)][0], fiyat = pmenusozluk[(siparis)][1] , icindekiler=pmenusozluk[(siparis)][2] , boy = boy, kenar = kenar, sos = sos)
                print("Icındekıler: ", l3)
                pizza.siparis()  
                pizza.SiparisGoster()
        

#baharat yerini değiştir


        elif urun == "corba":
            x =  int(input("Lütfen kac adet çorba siparis edeceginizi giriniz: "))
            print(cmenu)
            for c in range(x):
              alınan = input("Lutfen {} numarali sıparısinizi gırınız" .format(c+1) )
              by = int(input("Baharat istiyorsanız lütfen 1'e , baharat istemiyorsanız lütfen 0'a basın."))
            if by == 1:
                baharat = input("Lütfen baharatı giriniz:")
                print(f"{baharat} ekleniyor")
            elif by == 0:
                pass
              
            corba =Çorba(isim=cmenusozluk[(alınan)][0], fiyat= cmenusozluk[alınan][1])
              
            corba.SiparisGoster()
              




#sos menüsü girelilm mi 
        elif urun == "makarna":
          
          y =  int(input("Lütfen kac adet makarna siparis edeceginizi giriniz: "))
          print(mmenu)
          for b in range(y):
            istenen = input("Lutfen {} numarali sıparısinizi gırınız" .format(b+1) )
            sos = input("Lütfen sos giriniz:")
            print(f"{sos} ekleniyor")
            makarna =Makarna(isim=mmenusozluk[(istenen)][0], fiyat= mmenusozluk[istenen][1])
            makarna.SiparisGoster()
            

        elif urun == "pilav":
            s =  int(input("Lütfen kac adet pilav siparis edeceginizi giriniz: "))
            print(imenu)
            for a in range(s):
              ilgili = input("Lutfen {} numarali sıparısinizi gırınız" .format(a+1) )
              pilav =Pilav(isim=imenusozluk[(ilgili)][0], fiyat= imenusozluk[ilgili][1], cesit =imenusozluk[(ilgili)][0] )
              pilav.SiparisGoster()
            
        elif urun == "icecek":
         ic =  int(input("Lütfen kac adet içecek siparis edeceginizi giriniz: "))
         print(icecek)
         for w in range(ic):
            ilgili = input("Lutfen {} numarali sıparısinizi gırınız" .format(w+1) )
            b = input("Lütfen içeceğinizin boyutunu giriniz: ")
            
            icecek = Icecek(isim=icmenusozluk[(ilgili)][0], fiyat= icmenusozluk[ilgili][1])
            icecek.SiparisGoster()
            
                

    durum = True
    if durum == True:
        break
# Out:
# Restorana hosgeldiniz
# =====MENU=====
#         Pizza
#         Corba
#         Makarna
#         Pilav
#         Icecek
# ==============
# MENU
#  ------MENU--------
#       1. Spagetti
#       2. kelebek makarna
#       3.  boncuk makarna
# pesto ekleniyor
# AD-Soyad:f, Sipariş: Spagetti, Sos: pesto Fiyat:10, Kalan Bütçe: 12
# pesto ekleniyor
# AD-Soyad:f, Sipariş: Spagetti, Sos: pesto Fiyat:10, Kalan Bütçe: 12
# yok ekleniyor
# AD-Soyad:f, Sipariş: Kelebek, Sos: yok Fiyat:12, Kalan Bütçe: 10
