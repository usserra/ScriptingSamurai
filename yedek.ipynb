# %%
menu = {"pizza": 25, "çorba": 30, "makarna": 40, "kuru fasulye": 7, "pilav": 50}
print("=====MENU=====")
for i in list(menu.keys()):
    print(f"{i} : {menu[i]}")
print("==========")
adS = input("Lütfen isim-soyisim giriniz")
Budget = int(input("Lütfen bütçenizi giriniz: "))
kisi = int(input("Lütfen kaç kişinin sipariş vereceğini giriniz: "))
class Menu:
  def __init__(self,isim,fiyat, icindekiler):
    self.isim = isim
    self.fiyat = fiyat
    self.icindekiler = icindekiler
class Pizza(Menu):
  def __init__(self, isim, fiyat, icindekiler,boy,kenar,sos):
      super().__init__(isim, fiyat, icindekiler)
      self.boy = boy
      self.kenar = kenar
      self.sos = sos
  def siparis(self):
    s = input("siparisi onayliyor musunuz?: ")
    print(s)
    if s == "hayir":
        e = input(("Eklemek ıstedıgınız urun: "))
        c = input(("cıkartmak ıstedıgınız urun"))
        if e == "yok":
           pass
        else:       
            l1.append(e)
        if c == "yok":
            pass
        else: 
            l1.remove(c)
    else:
        print("siparisiniz kaydedildi")
    
  
class Çorba(Menu):
    def __init__(self, isim, fiyat, icindekiler, baharat):
      super().__init__(isim, fiyat, icindekiler)
      self.baharat = baharat
    def SiparisGoster(self):
          return f"AD-Soyad:{adS}, Sipaariş: {self.isim}, Fiyat:{self.fiyat}, İçindekiler: {self.icindekiler},Baharatı: {self.baharat}, Kalan Bütçe: {Budget-self.fiyat}"
class Makarna(Menu):
    def __init__(self, isim, fiyat, icindekiler,sos):
      super().__init__(isim, fiyat, icindekiler)
      self.sos = sos
    def SiparisGoster(self):
           return f"AD-Soyad:{adS}, Sipaariş: {self.isim}, Fiyat:{self.fiyat}, İçindekiler: {self.icindekiler}, Kalan Bütçe: {Budget-self.fiyat}"
class Kuru_Fasulye(Menu):
    def __init__(self, isim, fiyat, icindekiler):
      super().__init__(isim, fiyat, icindekiler)
    def SiparisGoster(self):
            return f"AD-Soyad:{adS}, Sipaariş: {self.isim}, Fiyat:{self.fiyat}, İçindekiler: {self.icindekiler}, Kalan Bütçe: {Budget-self.fiyat}"
class Pilav(Menu):
    def __init__(self, isim, fiyat, icindekiler,cesit):
      super().__init__(isim, fiyat, icindekiler)
      self.cesit = cesit
    def SiparisGoster(self):
            return f"AD-Soyad:{adS}, Sipaariş: {self.isim}, Fiyat:{self.fiyat}, İçindekiler: {self.icindekiler}, Sosu: {self.sos}, Kalan Bütçe: {Budget-self.fiyat}"

#hata bloğ u menüde olmayanlaar için ne yapılacağı, menüler, içindekieri değiştirebilir kullanıcı, 
pmenu = (""" ------MENU--------
      1. Margarıta
      2. VeggıePızza
      3. Etlı Pızza""")
pmenusozluk = {"1"  : ("Margarita", 10), "2" : ("VeggiePizza" , 12), "3" : ("EtliPizza" , 15)}

l1 = ["mozarella", "domates"]
l2 = ["mozarella", "domates", "biber", "patlican"]
l3 = ["mozarella", "domates", "sucuk"]

while True:
    secim = int(input("Sipariş vermek istiyorsanız lütfen 1'e , sipariş vermek istemiyorsanız lütfen 0'a basın."))
    if secim == 0:
       break
    elif secim == 1:
        urun = input("Sıparıs vermek ıstedıgınız urunu secın: ")
        print("MENU")

        if urun == "pizza":
          
          print(pmenu)
          while True:
            siparis = input("Lutfen sıparıs numaranızı gırınız, cikmak icin 'x' e basiniz: ")
            if siparis == "1":
                print("Icındekıler: ", l1)
                pizza.siparis()   
            elif siparis == "2":
                print("Icındekıler: ", l2)
                pizza.siparis()
            elif siparis == "3":
                print("Icındekıler: ", l3)
                pizza.siparis()
            elif siparis == "x":
                break

            boy =input("Lütfen boyutunu giriniz:")
            kenar = input("Lütfen kenarı giriniz:")
            sos = input("Lutfen sos giriniz: ")
    pizza = Pizza(isim= pmenusozluk[siparis], fiyat = pmenusozluk[siparis] , icindekiler=l1 , boy = boy, kenar = kenar, sos = sos)
            
            

        #print(pizza.icindekiler)

          
"""        elif urun == "çorba":
        #pizza menüsü eklenecek
          by = int(input("Baharat istiyorsanız lütfen 1'e , baharat istemiyorsanız lütfen 0'a basın."))
          if by == 1:
              baharat = input("Lütfen baharatı giriniz:")
              print(f"{baharat} ekleniyor")
          elif by == 0:
            continue
          
        print("Siparişiniz hazırlanıyor.")

        elif urun == "makarna":
         #pizza menüsü eklenecek
        sos = input("Lütfen sos giriniz:")
          print(f"{sos} ekleniyor")  
        
        elif urun == "Kuru Fasulya":
        #pizza menüsü eklenecek

        elif urun == "pilav":
        #pizza menüsü eklenecek
          cesit = input("Lütfen çeşidini giriniz:")
          print(f"{cesit} ekleniyor")
    elif secim == 0:
      break    
try:
   if not urun in menu:
except:
  print("Seçiminizi menüde bulamadık. Lütfen menüde yer alan bir tercih yapınız.")
    
    elif secim == 0:
      break"""

#selam

#bunu görebiliyorsan altına evet yaz

#yemek = input("Lütfen yemek istediğiniz yemeğin ismini giriniz:")
#cesit = input("Yemek istediğniz yemeğin çeşidini giriniz: ")
#sos = input("Yemek istediğniz yemeğin sos çeşidini giriniz: ")
#boyut = input("Yemek istediğniz boyutunu çeşidini giriniz: ")
#kcesit = input("Yemek istediğniz yemeğin kenar çeşidini giriniz: ")
#ic = input("Yemek istediğniz yemeğin içindekilerini giriniz: ")
# Out:
# =====MENU=====
# pizza : 25
# çorba : 30
# makarna : 40
# kuru fasulye : 7
# pilav : 50
# ==========
# MENU
#  ------MENU--------
#       1. Margarıta
#       2. VeggıePızza
#       3. Etlı Pızza
# Icındekıler:  ['mozarella', 'domates']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/serraus/Documents/GitHub/ScriptingSamurai/yedek.ipynb Cell 1 in 8
#      <a href='vscode-notebook-cell:/Users/serraus/Documents/GitHub/ScriptingSamurai/yedek.ipynb#W0sZmlsZQ%3D%3D?line=85'>86</a> if siparis == "1":
#      <a href='vscode-notebook-cell:/Users/serraus/Documents/GitHub/ScriptingSamurai/yedek.ipynb#W0sZmlsZQ%3D%3D?line=86'>87</a>     print("Icındekıler: ", l1)
# ---> <a href='vscode-notebook-cell:/Users/serraus/Documents/GitHub/ScriptingSamurai/yedek.ipynb#W0sZmlsZQ%3D%3D?line=87'>88</a>     pizza.siparis()
#      <a href='vscode-notebook-cell:/Users/serraus/Documents/GitHub/ScriptingSamurai/yedek.ipynb#W0sZmlsZQ%3D%3D?line=88'>89</a> elif siparis == "2":
#      <a href='vscode-notebook-cell:/Users/serraus/Documents/GitHub/ScriptingSamurai/yedek.ipynb#W0sZmlsZQ%3D%3D?line=89'>90</a>     print("Icındekıler: ", l2)
#
# NameError: name 'pizza' is not defined
